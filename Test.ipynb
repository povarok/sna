# %%
import tweepy
from tweepy import OAuthHandler
import json

# %%
consumer_key = '18knUKPT3wHtv9EPTiHVMspQw'
consumer_secret = 'mQek3pSitse7EhKCzcN7vTzLnRdw5jxSxXdANWnDeyCo8SPCi1'
access_token = '462140586-Ek5BulvlCS4G5S4M31AXJZEiCcpLPLK2KlYkvaJw'
access_secret = 'pDQQWBR27RAbvySnwJsFCm1JdV3SfbCRtCKi2CPY7cV41'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
#Загрузка новостей из фида
i = 0 
for status in tweepy.Cursor(api.home_timeline).items(5):
    # Process a single status
    print(i)
    print(status.text)
    i+=1
# Out:
# 0
# This weekend: Hold the gates – or breach them – in the Battle at the Gates event!
# The Clans have laid siege to Arge… https://t.co/pmylcoKgKl
# 1
# https://t.co/CJ8NFwh3mS
#
# У Факера
# 2
# we live https://t.co/p2o1COJUsr
# 3
# https://t.co/VRhZHoNGI3
#
# Присоединяйтесь, через 15 минут интервью с Вилатом
# 4
# Паша молодец D: https://t.co/iWp3H94eWf

# %%
def process_or_store(tweet):
    print(json.dumps(tweet))
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    process_or_store(status._json)
# Out:
# {"created_at": "Tue Apr 10 16:28:02 +0000 2018", "id": 983743419045511170, "id_str": "983743419045511170", "text": "This weekend: Hold the gates \u2013 or breach them \u2013 in the Battle at the Gates event!\nThe Clans have laid siege to Arge\u2026 https://t.co/pmylcoKgKl", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/pmylcoKgKl", "expanded_url": "https://twitter.com/i/web/status/983743419045511170", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 4754222719, "id_str": "4754222719", "name": "Eternal Card Game", "screen_name": "EternalCardGame", "location": "", "description": "Join the battle for the Eternal Throne in the free strategy
# ...

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
class MyListener(StreamListener):
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#чм2018','#футбол','#Россия'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1520         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1521             raise WantReadError()
#    1522         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from textblob import TextBlob
import nltk
text = "Python is a high-level, general-purpose programming language so really ."
wiki = TextBlob(text)
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN'),
#  ('so', 'RB'),
#  ('really', 'RB')]

# %%
#Saving data like this
wiki.sentiment.polarity
#Out array structure - 2018.12.01 - text of tweet
# Out:
# 0.2

# %%
from textblob import TextBlob
#array = ["bad","nice","good","very bad"]
array = [{"text":"bad", "author":"chelik1"},
          {"text":"nice", "author":"chelik2"},
          {"text":"good", "author":"chelik3"},
          {"text":"very bad", "author":"chelik4"},
          {"text":"absolutely nice and bad", "author":"chelik5"}]
print (array)
print ("\n")
i=0
for twit in array:
    twit = TextBlob(twit["text"])
    twit = twit.sentiment.polarity
    array[i]["polarity"]=twit
    i+=1
    
print (array)
# Out:
# [{'text': 'bad', 'author': 'chelik1'}, {'text': 'nice', 'author': 'chelik2'}, {'text': 'good', 'author': 'chelik3'}, {'text': 'very bad', 'author': 'chelik4'}, {'text': 'absolutely nice and bad', 'author': 'chelik5'}]
#
#
# [{'text': 'bad', 'author': 'chelik1', 'polarity': -0.6999999999999998}, {'text': 'nice', 'author': 'chelik2', 'polarity': 0.6}, {'text': 'good', 'author': 'chelik3', 'polarity': 0.7}, {'text': 'very bad', 'author': 'chelik4', 'polarity': -0.9099999999999998}, {'text': 'absolutely nice and bad', 'author': 'chelik5', 'polarity': -0.04999999999999993}]
