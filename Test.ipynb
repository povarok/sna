# %%
import tweepy
from tweepy import OAuthHandler
import json

# %%
consumer_key = '18knUKPT3wHtv9EPTiHVMspQw'
consumer_secret = 'mQek3pSitse7EhKCzcN7vTzLnRdw5jxSxXdANWnDeyCo8SPCi1'
access_token = '462140586-Ek5BulvlCS4G5S4M31AXJZEiCcpLPLK2KlYkvaJw'
access_secret = 'pDQQWBR27RAbvySnwJsFCm1JdV3SfbCRtCKi2CPY7cV41'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
#Загрузка новостей из фида
i = 0 
for status in tweepy.Cursor(api.home_timeline).items(5):
    # Process a single status
    print(i)
    print(status.text)
    i+=1
# Out:
# 0
# ПИЗДЕЛ НА МЕНЯ ТЫ ПИЗДЕЦ БОГУЛЬНИК
# 1
# Hearthstone! https://t.co/scfC9wBnpR
# 2
# 2:2….
# 3
# RT @athene_n0ctua: В РУССКОМ РЕПЕ ЕБАНЫЙ ШИППЕР https://t.co/i4Hy7TIrRx
# 4
# ХАСКИ ВЫПИЛ АЯХУАСКИ

# %%
#

def process_or_store(tweet):
    print(json.dumps(tweet))
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    process_or_store(status._json)
# Out:
# {"created_at": "Tue May 29 19:02:55 +0000 2018", "id": 1001539399216259073, "id_str": "1001539399216259073", "text": "[Hearthstone] Double Legend! OTK Priest Gets The Prize: https://t.co/T9JcgfJYQl via @YouTube", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "YouTube", "name": "YouTube", "id": 10228272, "id_str": "10228272", "indices": [84, 92]}], "urls": [{"url": "https://t.co/T9JcgfJYQl", "expanded_url": "http://youtu.be/9i2pJNFgW_w?a", "display_url": "youtu.be/9i2pJNFgW_w?a", "indices": [56, 79]}]}, "source": "<a href=\"http://www.google.com/\" rel=\"nofollow\">Google</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 579648949, "id_str": "579648949", "name": "TSM Kripparrian", "screen_name": "Kripparrian", "location": "", "description": "Gamer YouTuber Streamer Joker. Follow my better half @underflow
# ...

# %%
# заполнение БД в реальном времени Эдик

from tweepy import Stream
from tweepy.streaming import StreamListener
class MyListener(StreamListener):
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(json.dumps(data))
                print (json.dumps(data))
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print('error' + str(status))
        time.sleep(200)
        return True
 
twitter_stream = Stream(auth, MyListener())
#twitter_stream.filter(track=['#чм2018','#футбол','#Россия'])
twitter_stream.filter(track=['#Fallout'])
                        #КраткоеОписаниеСериала

# %%
from textblob import TextBlob
import nltk
text = "Python is a high-level, general-purpose programming language so really ."
wiki = TextBlob(text)
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN'),
#  ('so', 'RB'),
#  ('really', 'RB')]

# %%
#Saving data like this
wiki.sentiment.polarity
#Out array structure - 2018.12.01 - text of tweet
# Out:
# 0.2

# %%
#вывод обработанного массива
from textblob import TextBlob
from textblob import Blobber
from textblob.sentiments import NaiveBayesAnalyzer
import nltk
import pandas as pd
import re
import numpy as np
import pymongo
from pymongo import MongoClient
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, KeywordsOptions


filename = "fifa_world_cup_russia.csv"
#Requirements for Watson

natural_language_understanding = NaturalLanguageUnderstandingV1(
  username='a6a6b0d5-370e-42b1-8391-97f12a99fb19',
  password='tK7MknYJsSGI',
  version='2018-03-16')


def keywords(text):
    json_output = natural_language_understanding.analyze(
    text=text,
    features=Features(
    keywords=KeywordsOptions(
      sentiment=True,
      emotion=True,
      limit=2)))
    return json_output


    

def csv_parser(filename):
    df = pd.read_csv(filename,sep=';')
    array = []

    for index in df.index:
        
        Dict={}
        excess= re.search('[\S]*.[a-z]{0,6}/[\S]*',df['text'][index])
        if excess != None:
            new_text=df['text'][index].replace(excess.group(),'')
        else:
            new_text=df['text'][index]
        new_text=new_text.lower()
        Dict['text']= new_text
        Dict['date']=df['date'][index].split(' ')[0]
        Dict['language']=df['language'][index]
        array.append(Dict)
        
    #client = MongoClient('mongodb://localhost:27017/')
    #client = pymongo.MongoClient("mongodb://povarok:EDCFVgb1@cluster0-shard-00-00-watg3.mongodb.net:27017,cluster0-shard-00-01-watg3.mongodb.net:27017,cluster0-shard-00-02-watg3.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin")
    
    #db = client['productiondb']
    #db.fifa2018_russia.insert_many(array)
    return(array)

csv_parser(filename)
#for x in array: print(x)
#print ("\n")


def named_entities(text):


    parse_tree = nltk.ne_chunk(nltk.tag.pos_tag(text.split()), binary=True)  # POS tagging before chunking!

    named_entities = []

    for t in parse_tree.subtrees():
        if t.label() == 'NE':    #тут мы добавляем фильтр, какие штуки из предложения нам нужны
            #named_entities.append(t)
            named_entities.append(list(t))  # if you want to save a list of tagged words instead of a tree
    return named_entities
    


# метод обработки массива твитов
def text_analysis (array):
    result = []
    tb = Blobber(analyzer=NaiveBayesAnalyzer())
    for tweet in array:
        
        tweet["polarity"] = tb(tweet["text"]).sentiment.p_pos - tb(tweet["text"]).sentiment.p_neg #добавляем поле полярность твита в именованый массив
        #print ('twit["polarity"]' + str(twit["polarity"]))
        tweet["noun_phrases"] = TextBlob(tweet["text"]).noun_phrases  # непонятно что это.  .. , но тоже добавляем
        tweet["named_entities"] = named_entities(tweet["text"])

        try:
            print ('tweet[text]' + tweet['text'])
            tweet_keyword = keywords(tweet['text'])
            tweet_keyword = tweet_keyword['keywords']
            tweet["keywords"] = tweet_keyword
        except:
            pass
        result.append(tweet)
    return result
    
    
result_array=(text_analysis(csv_parser(filename)))  

#for x in result_array: 
#    print(x)
#    print('\n')
# Out:
# tweet[text]sabia que colors" no era una canción digna para el mundial. valio la pena la espera para poder encontrar esta otra, es perfecta debe ser el tema oficial fifa world cup russia 2018 me encanto"
# tweet[text]what do you say – you and me get to watch a fifa world cup match live in russia this june? sign up via this link and i’ll take you with me!  …
# tweet[text]34 days to go fifa world cup russia
# tweet[text]أعجبني فيديو @ youtube على  fifa world cup russia 2018 (official video preview) tristans football
# tweet[text]get to watch a fifa world cup match live in russia this june? sign up via this link  …
# tweet[text]fifa world cup russia 2018 sticker album:  via @ youtube
# tweet[text]what do you say – you and me get to watch a fifa world cup match live in russia this june? sign up via this link and i’ll take you with me!
# ...

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *

plotly.tools.set_credentials_file(username='sitozzz', api_key='EwikYFpX8xTpX1H0Axyy')

y_data = []
x_data = []
i = 0
#prepare arrays
for el in result_array:
    y_data.append(el['polarity'])
    x_data.append(i)
    i += 1
# Create traces

trace0 = go.Scatter(
    x = x_data,
    y = y_data,
    fill='tozerox',
    fillcolor='rgba(0,100,80,0.2)',
    line=Line(color='transparent'),
    mode = 'lines+markers',
    name = 'polarity'
    
)

data = [trace0]
# Edit the layout
layout = dict(title = 'Average polarity of tweets',
              paper_bgcolor='rgb(255,255,255)',
              plot_bgcolor='rgb(229,229,229)',
              xaxis = dict(title = 'Time(Now its just counter of tweets)'),
              yaxis = dict(title = 'Polarity'),
              )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='line-mode')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ...

# %%
import nltk

def extract_entity_names(t):
    entity_names = []

    if hasattr(t, 'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))

    return entity_names

with open('sample.txt', 'r') as f:
    for line in f:
        sentences = nltk.sent_tokenize(line)
        tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
        tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
        chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)

        entities = []
        for tree in chunked_sentences:
            entities.extend(extract_entity_names(tree))

        print(entities)
# Out:
# ['Denmark', 'CET']
# ['Location', 'Devon', 'England', 'GMT']
# ['Australia', 'Australian Eastern Standard Time']
# ['Eugene', 'Oregon', 'Seoul', 'South Korea', 'Pacific']
# ['London', 'United Kingdom', 'Norway', 'Israel', 'London', 'United Kingdom', 'Boston', 'United States', 'EDT']

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag, ne_chunk


def extract_entities(text):
    entities = []
    for sentence in sent_tokenize(text):
        chunks = ne_chunk(pos_tag(word_tokenize(sentence)))
        entities.extend([chunk for chunk in chunks if hasattr(chunk, 'node')])
    return entities



text = """
A multi-agency manhunt is under way across several states and Mexico after
police say the former Los Angeles police officer suspected in the murders of a
college basketball coach and her fiancÃ© last weekend is following through on
his vow to kill police officers after he opened fire Wednesday night on three
police officers, killing one.
"In this case, we're his target," Sgt. Rudy Lopez from the Corona Police
Department said at a press conference.
The suspect has been identified as Christopher Jordan Dorner, 33, and he is
considered extremely dangerous and armed with multiple weapons, authorities
say. The killings appear to be retribution for his 2009 termination from the
 Los Angeles Police Department for making false statements, authorities say.
Dorner posted an online manifesto that warned, "I will bring unconventional
and asymmetrical warfare to those in LAPD uniform whether on or off duty."
"""
entities = []
for sentence in sent_tokenize(text):
        chunks = ne_chunk(pos_tag(word_tokenize(sentence)))
        entities.extend([chunk for chunk in chunks if hasattr(chunk, 'node')])
print (entities)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-65-a749326b31da> in <module>()
#      30 for sentence in sent_tokenize(text):
#      31         chunks = ne_chunk(pos_tag(word_tokenize(sentence)))
# ---> 32         entities.extend([chunk for chunk in chunks if hasattr(chunk, 'node')])
#      33 print (entities)
#
# <ipython-input-65-a749326b31da> in <listcomp>(.0)
#      30 for sentence in sent_tokenize(text):
#      31         chunks = ne_chunk(pos_tag(word_tokenize(sentence)))
# ---> 32         entities.extend([chunk for chunk in chunks if hasattr(chunk, 'node')])
#      33 print (entities)
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in _get_node(self)
#     200     def _get_node(self):
#     201         """Outdated method to access the node value; use the label() method instead."""
# ...

# %%
import numpy as np
import pymongo
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
db = client['productiondb']

db.main.insert_many(result_array)

x = db.main.find()
print ("sdf" +  str(len(list(x))))
#x = db.main.find({"date": "2018-04-20"})
#summ = 0

#------------------------ для графика со средними значениями полярности
def get_avg_polarity(mongoArray):    
    avg_pol = {}
    for i in mongoArray:
        if i["date"] in avg_pol:
            avg_pol[i["date"]].append(i["polarity"])
        else:
            avg_pol[i["date"]] = []
            avg_pol[i["date"]].append(i["polarity"])

    for key in avg_pol.keys():
        avg_pol[key] = np.mean(avg_pol[key])
    return avg_pol

out = get_avg_polarity(x)
print (list(out.values()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ffc83cff0552> in <module>()
#       6 db = client['productiondb']
#       7
# ----> 8 db.main.insert_many(result_array)
#       9
#      10 x = db.main.find()
#
# NameError: name 'result_array' is not defined

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly

trace0 = go.Bar(
    x=list(out.keys()),
    y=list(out.values()),
    name='Avg polarity',
    marker=dict(
        color='rgb(49,130,189)'
    )
)


data = [trace0]
layout = go.Layout(
    xaxis=dict(tickangle=-45),
    barmode='group',
)

fig = go.Figure(data=data, layout=layout)
#Оффлайн
#plotly.offline.plot(fig, filename="avg_polarity.html")
py.iplot(fig, filename='avg_polarity')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sitozzz/13.embed" height="525px" width="100%"></iframe>

# %%
x = [1,3,5,6]
print (len(x))
# Out:
# 4

# %%
# подключение облачного сервиса MongoDB Atlas для загрузки твитов
import pymongo
from pymongo import MongoClient



#по идее нужно юзать это но не работает.
#client = pymongo.MongoClient("mongodb+srv://povarok:EDCFVgb1@cluster0-watg3.mongodb.net/test")

client = pymongo.MongoClient("mongodb://povarok:EDCFVgb1@cluster0-shard-00-00-watg3.mongodb.net:27017,cluster0-shard-00-01-watg3.mongodb.net:27017,cluster0-shard-00-02-watg3.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin")
db = client['productiondb']

#пример ввода данных
#db.fifa_world_cup_russia.insert_many(result_array)
#db.main.insert_many(result_array)

#пример вывода 
x = "fifa2018_russia"
arr = db[x].find({}, {"text": 1} )
print (type(arr))
result = []
for tweet in arr:
    result.append(tweet.get("text"))
    
arr = list(arr)
#for el in arr:
#    el.pop('_id')
#print (arr)
client.close()
print (result)
#t = json.dumps(list(arr), sort_keys=True, indent=4)

#print (len(list(arr)))
# Out:
# <class 'pymongo.cursor.Cursor'>
# ...

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
blob = TextBlob("I love this library", analyzer=NaiveBayesAnalyzer())
blob.sentiment.p_pos
# Out:
# Sentiment(classification='pos', p_pos=0.7996209910191279, p_neg=0.2003790089808724)

# %%
from textblob import Blobber
from textblob.sentiments import NaiveBayesAnalyzer
tb = Blobber(analyzer=NaiveBayesAnalyzer())

print('jko'+tb("Fuck").sentiment.classification)




def sentiment_calc(text):
    try:
        return tb(text).sentiment.p_pos
    except:
        return None
# Out:
# jkoneg

# %%
import json

t = [{"name": "vasya", "surname":"komarov"},{"name": "leha", "surname":"urfu"}]

print (type(t))
t = json.dumps(t)

print (type(t))

t  = json.loads(t)
print (type(t))
# Out:
# <class 'list'>
# <class 'str'>
# <class 'list'>

# %%
import pymongo
from pymongo import MongoClient
import re

client = pymongo.MongoClient("mongodb://povarok:EDCFVgb1@cluster0-shard-00-00-watg3.mongodb.net:27017,cluster0-shard-00-01-watg3.mongodb.net:27017,cluster0-shard-00-02-watg3.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin")
db = client['productiondb']


def f4(d):
    return [k for k,v in d.items() if v==max(d.values())][0]    


reg = re.compile('[^a-zA-Z ]')


data = db.fifa2018_russia.find()
data = list(data)
result = {}
#print((data[0]['text']).split(' '))
for i in data:
    sentence = i['noun_phrases']#reg.sub('', i['text']).split(' ')
    for word in sentence:
        if word in result:
            if  len(word) > 2:
                result[word]+=1
        else:
            if  len(word) > 2:
                result[word]=1
print ("result filled")

popular_words = {}
for i in range (20):
    print ("tst")
    popular_words[f4(result)] = result.pop(f4(result))
    
    
    
                
print (popular_words)
# Out:
# result filled
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# tst
# {'fifa world cup russia': 2869, 'world cup': 1591, 'homeless animals': 806, 'bloody fifa': 573, '@ youtube': 570, 'official video': 514, '# diamondvisa card': 301, 'i ’ ll': 294, '# lightuptheworldcup': 282, '@ budweiserindia': 280, '# russia': 275, 'russia world cup': 258, 'gustado un vídeo': 204, 'new post': 194, 'fan racism': 193, 'fifa world cup™': 193, 'world cup russia': 165, 'super eagles': 160, '# lightuptheworldcup @ budweiserindia': 159, 'fifa charges world cup host russia': 154}

# %%
to_db = {"text":"pop_words","named_entities":[popular_words]}

db.fifa2018_russia.insert_one(to_db)

# %%
network = db.fifa2018_russia.find({'text':'pop_words'})
print (list(network[0]["named_entities"][0].keys()))
# Out:
# ['fifa world cup russia', 'world cup', 'homeless animals', 'bloody fifa', '@ youtube', 'official video', '# diamondvisa card', 'i ’ ll', '# lightuptheworldcup', '@ budweiserindia', '# russia', 'russia world cup', 'gustado un vídeo', 'new post', 'fan racism', 'fifa world cup™', 'world cup russia', 'super eagles', '# lightuptheworldcup @ budweiserindia', 'fifa charges world cup host russia']
